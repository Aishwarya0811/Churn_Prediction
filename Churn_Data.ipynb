# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Churn_telecom.csv')
data.head()
# Out:
#    rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0   23.9975    219.25       22.500   0.2475         0.00          0.0
# 1   57.4925    482.75       37.425   0.2475        22.75          9.1
# 2   16.9900     10.25       16.990   0.0000         0.00          0.0
# 3   38.0000      7.50       38.000   0.0000         0.00          0.0
# 4   55.2300    570.50       71.980   0.0000         0.00          0.0
#
#    vceovr_Mean  datovr_Mean  roam_Mean  rev_Range     ...       kid0_2  \
# 0          0.0          0.0        0.0      25.99     ...            U
# 1          9.1          0.0        0.0     153.14     ...            U
# 2          0.0          0.0        0.0       0.00     ...            U
# 3          0.0          0.0        0.0       0.00     ...            Y
# 4          0.0          0.0        0.0       0.00     ...            U
#
#    kid3_5  kid6_10  kid11_15  kid16_17  creditcd  car_buy  retdays  eqpdays  \
# ...

# %%
data.shape
# Out:
# (100000, 173)

# %% [markdown]
# # Remove rows from a dataframe if 75% of its column = 0

# %%
df = data.loc[:,data.isnull().mean()<.8]

# %%
df.shape
# Out:
# (100000, 159)

# %%
df.head()
# Out:
#    rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0   23.9975    219.25       22.500   0.2475         0.00          0.0
# 1   57.4925    482.75       37.425   0.2475        22.75          9.1
# 2   16.9900     10.25       16.990   0.0000         0.00          0.0
# 3   38.0000      7.50       38.000   0.0000         0.00          0.0
# 4   55.2300    570.50       71.980   0.0000         0.00          0.0
#
#    vceovr_Mean  datovr_Mean  roam_Mean  rev_Range     ...       ethnic  \
# 0          0.0          0.0        0.0      25.99     ...            N
# 1          9.1          0.0        0.0     153.14     ...            Z
# 2          0.0          0.0        0.0       0.00     ...            N
# 3          0.0          0.0        0.0       0.00     ...            U
# 4          0.0          0.0        0.0       0.00     ...            I
#
#    kid0_2  kid3_5  kid6_10  kid11_15  kid16_17  creditcd  car_buy  eqpdays  \
# ...

# %%
df.isna().sum()
# Out:
# rev_Mean           357
# mou_Mean           357
# totmrc_Mean        357
# da_Mean            357
# ovrmou_Mean        357
# ovrrev_Mean        357
# vceovr_Mean        357
# datovr_Mean        357
# roam_Mean          357
# rev_Range          357
# mou_Range          357
# totmrc_Range       357
# da_Range           357
# ovrmou_Range       357
# ovrrev_Range       357
# vceovr_Range       357
# datovr_Range       357
# roam_Range         357
# change_mou         891
# change_rev         891
# drop_vce_Mean        0
# drop_dat_Mean        0
# blck_vce_Mean        0
# blck_dat_Mean        0
# unan_vce_Mean        0
# unan_dat_Mean        0
# plcd_vce_Mean        0
# plcd_dat_Mean        0
# recv_vce_Mean        0
# recv_sms_Mean        0
#                  ...
# rv                1732
# occu1            73353
# ownrent          33706
# lor              30190
# dwlltype         31909
# marital           1732
# mailordr         64363
# age1              1732
# age2              1732
# ...

# %%
# Dropping columns which are not relevant for churn as per description given

# %%
df['HHstatin'].head()
# Out:
# 0    C
# 1    C
# 2    C
# 3    C
# 4    C
# Name: HHstatin, dtype: object

# %%
x = df.drop(['Customer_ID', 'HHstatin','truck','lor','ethnic','kid0_2','kid3_5','kid6_10','kid11_15','kid16_17','creditcd','car_buy','children','proptype','dwllsize','infobase'], axis=1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

# %%
corr = x.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col0 {
#             background-color:  #b40426;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col1 {
#             background-color:  #f18f71;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col2 {
#             background-color:  #f7b396;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col3 {
#             background-color:  #d4dbe6;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col4 {
#             background-color:  #ee8468;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col5 {
#             background-color:  #ed8366;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col6 {
#             background-color:  #ee8468;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col7 {
#             background-color:  #799cf8;
#         }    #T_1daa499e_5411_11e9_9f14_a0999b0c835drow0_col8 {
#             background-color:  #bcd2f7;
# ...

# %%
Correl = x[x.columns[1:]].corr()['churn'][:]

# %%
Descending = Correl.sort_values(ascending = False)

# %%
Descending.head(15)
# Out:
# churn           1.000000
# eqpdays         0.112691
# uniqsubs        0.039882
# vceovr_Range    0.030613
# ovrrev_Range    0.030043
# ovrmou_Range    0.027485
# vceovr_Mean     0.024240
# ovrrev_Mean     0.023736
# months          0.020991
# ovrmou_Mean     0.019720
# actvsubs        0.019686
# rev_Range       0.019421
# mou_Range       0.009642
# roam_Mean       0.009324
# mtrcycle        0.008278
# Name: churn, dtype: float64

# %%
feature = x.drop(['churn'], axis = 1)
target = x['churn']

# %%
df.a.astype(float).fillna(0.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ec85723a752c> in <module>
# ----> 1 int(float(feature))
#       2
#
# TypeError: float() argument must be a string or a number, not 'DataFrame'

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(feature)
X_test = scaler.transform(target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-5ef8cf46765b> in <module>
#       1 scaler = StandardScaler()
# ----> 2 X_train = scaler.fit_transform(feature)
#       3 X_test = scaler.transform(target)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     460         if y is None:
#     461             # fit method of arity 1 (unsupervised transformation)
# --> 462             return self.fit(X, **fit_params).transform(X)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     623         # Reset internal state before fitting
#     624         self._reset()
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_train_org, X_test_org, y_train, y_test = train_test_split(feature, target, random_state = 20, test_size = 0.2)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)
log_clf = LogisticRegression()
log_clf.fit(X_train, y_train)
